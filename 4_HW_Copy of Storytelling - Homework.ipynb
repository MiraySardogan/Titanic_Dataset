# %% [markdown]
# In this homework you will take the role of a researcher working on a database with the passengers of the Titanic ship which sunk. You are trying to understand what patterns there are in the passengers who survived, and you want to answer the question: what predicted that a passenger would survive?
#
# Please come up with 3 hypothesis of what might predict that a passenger will survive, and show your work. It is ok if you find some things that do not predict at all, or that negatively predict that a passenger will survive. For each hypothesis, make explicit what your hypothesis or question is, make a plot that tries to answer that hypothesis, and explicitely describe your conclusion (i.e. was your hypothesis correct? what is the answer to your question?).

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic = sns.load_dataset("titanic")

# %%
#Example hypothesis: maybe the people on the upper decks were more likely to survive!
#(For reference, the decks are ordered in alphabetical order, so deck A was at the top, and G at the bottom of the ship).
sns.barplot(data=titanic, x = 'deck', y = "survived")
# Out:
# <Axes: xlabel='deck', ylabel='survived'>

# %% [markdown]
# As we can see, it seems like there is not much of a correlation between the deck and the survival rate! (In case you are curious, the column "deck" is actually missing a lot of entries. You can confirm this by running::
#  titanic.isna().sum()
#
#  So, just in the case of using the deck, the database is not really reliable.)

# %%
titanic.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#Work on your hypothesis 1 here
#alone-survived

sns.countplot(data=titanic, x= 'alone')

plt.title("Survival Count for Passengers Who Were Alone or Not Alone")
# Out:
# Text(0.5, 1.0, 'Survival Count for Passengers Who Were Alone or Not Alone')

# %% [markdown]
# Hypothesis 1 :The count of survivors among passengers who were not alone is higher than the count of survivors among passengers who were traveling alone. Therefore, passengers who were not alone had a higher survival rate.

# %%
sns.countplot(data=titanic, x='sex', hue='survived')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#Work on your hypothesis 2 here
#age and sex
A=titanic.query("sex =='female'")

#print(A)plt.figure(figsize=(8, 6))
sns.histplot(data=A, x='age', hue='survived', bins=20, element='step')

plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution of Female Passengers by Survival Status")
# Out:
# Text(0.5, 1.0, 'Age Distribution of Female Passengers by Survival Status')

# %%
A=titanic.query("sex =='male'")

#print(A)plt.figure(figsize=(8, 6))
sns.histplot(data=A, x='age', hue='survived', bins=20, element='step')

plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Distribution of Male Passengers by Survival Status")
# Out:
# Text(0.5, 1.0, 'Age Distribution of Male Passengers by Survival Status')

# %% [markdown]
# **Hypothesis 2 **:  Female passengers  had a better chance of survival than male passengers.
#
# **!!!!** In my opinion, age may not be a significant factor, but I would hypothesize that passengers over the age of 50 had a lower chance of survival. If I am incorrect, I would appreciate my teacher's guidance and correction.  :):)

# %%
#Work on your hypothesis 3 here
#####

# %%
titanic['class'].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
sns.barplot(data=titanic, x = 'class', y = "survived")
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
first_class = titanic[titanic['class']== 'First']
first_class
sns.histplot(data=first_class, x='embarked', hue='survived', bins=20, element='step')
# Out:
# <Axes: xlabel='embarked', ylabel='Count'>

# %% [markdown]
# **Hypothesis 3:** I'm uncertain about the most suitable plot for this scenario****************************************. I intend to investigate which embarkation point had a higher survival rate among passengers. While this may not be directly related to the city itself, it can indirectly reflect the economic status of the passengers' origins.  I aim to determine from which city passengers purchased first-class tickets, as we observed that first-class passengers had a higher survival rate. Ultimately, this analysis may help us identify the embarkation point with a potentially wealthier demographic.

# %%
#It identifies 'C' as the potentially wealthier city.
#Because, More people survived from the city 'C,' possibly because more first-class tickets were purchased by passengers from this location.
